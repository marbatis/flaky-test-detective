# %% [markdown]
# # Flaky Test Analysis
# Inspect synthetic CI history and score output.

# %%
from app.services.data_loader import DataLoader
from app.services.flake_scoring import FlakeScoring
df = DataLoader().load()
FlakeScoring().score(df).head(10)
